# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import datetime as dt
from scipy import stats
import numpy as np
from statsmodels.tsa.stattools import acf
from statsmodels.graphics.tsaplots import plot_acf

# %%
RIO = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\RIO.csv')
VALE = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\VALE.csv')
ECL = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\ECL.csv')
BHP = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\BHP.csv')
TX = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\TX.csv')
LYB = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\LYB.csv')
BA = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\BA.csv')
LMT = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\LMT.csv')
GE = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\GE.csv')
CAT = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\CAT.csv')
J = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\J.csv')
MMM = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\MMM.csv')
BAC = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\BAC.csv')
V = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\V.csv')
GS = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\GS.csv')
JPM = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\JPM.csv')
MS = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\MS.csv')
SCHW = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\SCHW.csv')
XOM = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\XOM.csv')
SLB = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\SLB.csv')
KMI = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\KMI.csv')
TSLA = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\TSLA.csv')
CVX = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\CVX.csv')
HAL = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\HAL.csv')
HD = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\HD.csv')
SBUX = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\SBUX.csv')
NKE = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\NKE.csv')
MCD = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\MCD.csv')
CCL = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\CCL.csv')
BKNG = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\BKNG.csv')
AAPL = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\AAPL.csv')
MSFT = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\MSFT.csv')
CSCO = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\CSCO.csv')
INTC = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\INTC.csv')
ORCL = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\ORCL.csv')
IBM = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\IBM.csv')
VZ = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\VZ.csv')
FB = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\FB.csv')
DIS = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\DIS.csv')
CMCSA = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\CMCSA.csv')
T = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\T.csv')
NFLX = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\NFLX.csv')
RDFN = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\RDFN.csv')
AMT = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\AMT.csv')
SPG = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\SPG.csv')
PSA = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\PSA.csv')
PLD = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\PLD.csv')
EQIX = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\EQIX.csv')
JNJ = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\JNJ.csv')
PFE = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\PFE.csv')
UNH = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\UNH.csv')
MRK = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\MRK.csv')
ANTM = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\ANTM.csv')
CI = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\CI.csv')
KO = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\KO.csv')
CL = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\CL.csv')
PG = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\PG.csv')
WMT = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\WMT.csv')
PEP = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\PEP.csv')
CLX = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\CLX.csv')
NEE = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\NEE.csv')
DUK = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\DUK.csv')
EXC = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\EXC.csv')
D = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\D.csv')
ES = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\ES.csv')
CNP = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\01_stocks\CNP.csv')
VNQ = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\02_ETFs\VNQ.csv')
XLB = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\02_ETFs\XLB.csv')
XLC = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\02_ETFs\XLC.csv')
XLE = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\02_ETFs\XLE.csv')
XLF = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\02_ETFs\XLF.csv')
XLI = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\02_ETFs\XLI.csv')
XLK = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\02_ETFs\XLK.csv')
XLP = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\02_ETFs\XLP.csv')
XLU = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\02_ETFs\XLU.csv')
XLV = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\02_ETFs\XLV.csv')
XLY = pd.read_csv(r'C:\Users\asee\Desktop\Springboard\Capstone 2\02_ETFs\XLY.csv')

# %%
AAPL.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  1980-12-12  0.513393  0.515625  0.513393  0.513393   0.406782  117258400
# 1  1980-12-15  0.488839  0.488839  0.486607  0.486607   0.385558   43971200
# 2  1980-12-16  0.453125  0.453125  0.450893  0.450893   0.357260   26432000
# 3  1980-12-17  0.462054  0.464286  0.462054  0.462054   0.366103   21610400
# 4  1980-12-18  0.475446  0.477679  0.475446  0.475446   0.376715   18362400

# %%
XLB.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  1998-12-22  20.781250  20.828125  20.750000  20.828125  12.881685    1900
# 1  1998-12-23  20.968750  21.140625  20.968750  21.046875  13.016976     700
# 2  1998-12-24  21.296875  21.531250  21.203125  21.531250  13.316548    1500
# 3  1998-12-28  21.500000  21.500000  21.312500  21.343750  13.200579    2500
# 4  1998-12-29  21.734375  21.734375  21.734375  21.734375  13.442181     100

# %%
SLB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9645 entries, 0 to 9644
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       9645 non-null   object
#  1   Open       9645 non-null   float64
#  2   High       9645 non-null   float64
#  3   Low        9645 non-null   float64
#  4   Close      9645 non-null   float64
#  5   Adj Close  9645 non-null   float64
#  6   Volume     9645 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 527.6+ KB

# %%
XLY.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5353 entries, 0 to 5352
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5353 non-null   object
#  1   Open       5353 non-null   float64
#  2   High       5353 non-null   float64
#  3   Low        5353 non-null   float64
#  4   Close      5353 non-null   float64
#  5   Adj Close  5353 non-null   float64
#  6   Volume     5353 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 292.9+ KB

# %%
#convert Date from object to datetime
RIO['Date']=pd.to_datetime(RIO['Date'])
VALE['Date']=pd.to_datetime(RIO['Date'])
ECL['Date']=pd.to_datetime(RIO['Date'])
BHP['Date']=pd.to_datetime(RIO['Date'])
TX['Date']=pd.to_datetime(RIO['Date'])
LYB['Date']=pd.to_datetime(RIO['Date'])
BA['Date']=pd.to_datetime(RIO['Date'])
LMT['Date']=pd.to_datetime(RIO['Date'])
GE['Date']=pd.to_datetime(RIO['Date'])
CAT['Date']=pd.to_datetime(RIO['Date'])
J['Date']=pd.to_datetime(RIO['Date'])
MMM['Date']=pd.to_datetime(RIO['Date'])
BAC['Date']=pd.to_datetime(RIO['Date'])
V['Date']=pd.to_datetime(RIO['Date'])
GS['Date']=pd.to_datetime(RIO['Date'])
JPM['Date']=pd.to_datetime(RIO['Date'])
MS['Date']=pd.to_datetime(RIO['Date'])
SCHW['Date']=pd.to_datetime(RIO['Date'])
XOM['Date']=pd.to_datetime(RIO['Date'])
SLB['Date']=pd.to_datetime(RIO['Date'])
KMI['Date']=pd.to_datetime(RIO['Date'])
TSLA['Date']=pd.to_datetime(RIO['Date'])
CVX['Date']=pd.to_datetime(RIO['Date'])
HAL['Date']=pd.to_datetime(RIO['Date'])
HD['Date']=pd.to_datetime(RIO['Date'])
SBUX['Date']=pd.to_datetime(RIO['Date'])
NKE['Date']=pd.to_datetime(RIO['Date'])
MCD['Date']=pd.to_datetime(RIO['Date'])
CCL['Date']=pd.to_datetime(RIO['Date'])
BKNG['Date']=pd.to_datetime(RIO['Date'])
AAPL['Date']=pd.to_datetime(RIO['Date'])
MSFT['Date']=pd.to_datetime(RIO['Date'])
CSCO['Date']=pd.to_datetime(RIO['Date'])
INTC['Date']=pd.to_datetime(RIO['Date'])
ORCL['Date']=pd.to_datetime(RIO['Date'])
IBM['Date']=pd.to_datetime(RIO['Date'])
VZ['Date']=pd.to_datetime(RIO['Date'])
FB['Date']=pd.to_datetime(RIO['Date'])
DIS['Date']=pd.to_datetime(RIO['Date'])
CMCSA['Date']=pd.to_datetime(RIO['Date'])
T['Date']=pd.to_datetime(RIO['Date'])
NFLX['Date']=pd.to_datetime(RIO['Date'])
RDFN['Date']=pd.to_datetime(RIO['Date'])
AMT['Date']=pd.to_datetime(RIO['Date'])
SPG['Date']=pd.to_datetime(RIO['Date'])
PSA['Date']=pd.to_datetime(RIO['Date'])
PLD['Date']=pd.to_datetime(RIO['Date'])
EQIX['Date']=pd.to_datetime(RIO['Date'])
JNJ['Date']=pd.to_datetime(RIO['Date'])
PFE['Date']=pd.to_datetime(RIO['Date'])
UNH['Date']=pd.to_datetime(RIO['Date'])
MRK['Date']=pd.to_datetime(RIO['Date'])
ANTM['Date']=pd.to_datetime(RIO['Date'])
CI['Date']=pd.to_datetime(RIO['Date'])
KO['Date']=pd.to_datetime(RIO['Date'])
CL['Date']=pd.to_datetime(RIO['Date'])
PG['Date']=pd.to_datetime(RIO['Date'])
WMT['Date']=pd.to_datetime(RIO['Date'])
PEP['Date']=pd.to_datetime(RIO['Date'])
CLX['Date']=pd.to_datetime(RIO['Date'])
NEE['Date']=pd.to_datetime(RIO['Date'])
DUK['Date']=pd.to_datetime(RIO['Date'])
EXC['Date']=pd.to_datetime(RIO['Date'])
D['Date']=pd.to_datetime(RIO['Date'])
ES['Date']=pd.to_datetime(RIO['Date'])
CNP['Date']=pd.to_datetime(RIO['Date'])
XLB['Date']=pd.to_datetime(RIO['Date'])
XLI['Date']=pd.to_datetime(RIO['Date'])
XLF['Date']=pd.to_datetime(RIO['Date'])
XLE['Date']=pd.to_datetime(RIO['Date'])
XLY['Date']=pd.to_datetime(RIO['Date'])
XLK['Date']=pd.to_datetime(RIO['Date'])
XLC['Date']=pd.to_datetime(RIO['Date'])
VNQ['Date']=pd.to_datetime(RIO['Date'])
XLV['Date']=pd.to_datetime(RIO['Date'])
XLP['Date']=pd.to_datetime(RIO['Date'])
XLU['Date']=pd.to_datetime(RIO['Date'])

# %%
RIO.set_index(['Date'], inplace=True)
VALE.set_index(['Date'], inplace=True)
ECL.set_index(['Date'], inplace=True)
BHP.set_index(['Date'], inplace=True)
TX.set_index(['Date'], inplace=True)
LYB.set_index(['Date'], inplace=True)
XLB.set_index(['Date'], inplace=True)
BA.set_index(['Date'], inplace=True)
LMT.set_index(['Date'], inplace=True)
GE.set_index(['Date'], inplace=True)
CAT.set_index(['Date'], inplace=True)
J.set_index(['Date'], inplace=True)
MMM.set_index(['Date'], inplace=True)
XLI.set_index(['Date'], inplace=True)
BAC.set_index(['Date'], inplace=True)
V.set_index(['Date'], inplace=True)
GS.set_index(['Date'], inplace=True)
JPM.set_index(['Date'], inplace=True)
MS.set_index(['Date'], inplace=True)
SCHW.set_index(['Date'], inplace=True)
XLF.set_index(['Date'], inplace=True)
XOM.set_index(['Date'], inplace=True)
SLB.set_index(['Date'], inplace=True)
KMI.set_index(['Date'], inplace=True)
TSLA.set_index(['Date'], inplace=True)
CVX.set_index(['Date'], inplace=True)
HAL.set_index(['Date'], inplace=True)
XLE.set_index(['Date'], inplace=True)
HD.set_index(['Date'], inplace=True)
SBUX.set_index(['Date'], inplace=True)
NKE.set_index(['Date'], inplace=True)
MCD.set_index(['Date'], inplace=True)
CCL.set_index(['Date'], inplace=True)
BKNG.set_index(['Date'], inplace=True)
XLY.set_index(['Date'], inplace=True)
AAPL.set_index(['Date'], inplace=True)
MSFT.set_index(['Date'], inplace=True)
CSCO.set_index(['Date'], inplace=True)
INTC.set_index(['Date'], inplace=True)
ORCL.set_index(['Date'], inplace=True)
IBM.set_index(['Date'], inplace=True)
XLK.set_index(['Date'], inplace=True)
VZ.set_index(['Date'], inplace=True)
FB.set_index(['Date'], inplace=True)
DIS.set_index(['Date'], inplace=True)
CMCSA.set_index(['Date'], inplace=True)
T.set_index(['Date'], inplace=True)
NFLX.set_index(['Date'], inplace=True)
XLC.set_index(['Date'], inplace=True)
RDFN.set_index(['Date'], inplace=True)
AMT.set_index(['Date'], inplace=True)
SPG.set_index(['Date'], inplace=True)
PSA.set_index(['Date'], inplace=True)
PLD.set_index(['Date'], inplace=True)
EQIX.set_index(['Date'], inplace=True)
VNQ.set_index(['Date'], inplace=True)
JNJ.set_index(['Date'], inplace=True)
PFE.set_index(['Date'], inplace=True)
UNH.set_index(['Date'], inplace=True)
MRK.set_index(['Date'], inplace=True)
ANTM.set_index(['Date'], inplace=True)
CI.set_index(['Date'], inplace=True)
XLV.set_index(['Date'], inplace=True)
KO.set_index(['Date'], inplace=True)
CL.set_index(['Date'], inplace=True)
PG.set_index(['Date'], inplace=True)
WMT.set_index(['Date'], inplace=True)
PEP.set_index(['Date'], inplace=True)
CLX.set_index(['Date'], inplace=True)
XLP.set_index(['Date'], inplace=True)
NEE.set_index(['Date'], inplace=True)
DUK.set_index(['Date'], inplace=True)
EXC.set_index(['Date'], inplace=True)
D.set_index(['Date'], inplace=True)
ES.set_index(['Date'], inplace=True)
CNP.set_index(['Date'], inplace=True)
XLU.set_index(['Date'], inplace=True)

# %%
materials = [RIO, VALE, ECL, BHP, TX, LYB, XLB]
industrials = [BA, LMT, GE, CAT, J, MMM, XLI]
financials = [BAC, V, GS, JPM, MS, SCHW, XLF]
energy = [XOM, SLB, KMI, TSLA, CVX, HAL, XLE]
consumer_discretionary = [HD, SBUX, NKE, MCD, CCL, BKNG, XLY]
info_tech = [AAPL, MSFT, CSCO, INTC, ORCL, IBM, XLK]
communication = [VZ, FB, DIS, CMCSA, T, NFLX, XLC]
real_estate = [RDFN, AMT, SPG, PSA, PLD, EQIX, VNQ]
health_care = [JNJ, PFE, UNH, MRK, ANTM, CI, XLV]
consumer_staple = [KO, CL, PG, WMT, PEP, CLX, XLP]
utilities = [NEE, DUK, EXC, D, ES, CNP, XLU]
etf = [XLB, XLI, XLF, XLE, XLY, XLK, XLC, VNQ, XLV, XLP, XLU]

# %%
#calculate moving averages
ma_day = [10, 20, 50]
for ma in ma_day:
    for company in materials:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        
ma_day = [10, 20, 50]
for ma in ma_day:
    for company in industrials:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()

ma_day = [10, 20, 50]
for ma in ma_day:
    for company in financials:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        
ma_day = [10, 20, 50]
for ma in ma_day:
    for company in energy:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        
ma_day = [10, 20, 50]
for ma in ma_day:
    for company in consumer_discretionary:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        
ma_day = [10, 20, 50]
for ma in ma_day:
    for company in info_tech:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        
ma_day = [10, 20, 50]
for ma in ma_day:
    for company in communication:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        
ma_day = [10, 20, 50]
for ma in ma_day:
    for company in real_estate:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        
ma_day = [10, 20, 50]
for ma in ma_day:
    for company in health_care:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        
ma_day = [10, 20, 50]
for ma in ma_day:
    for company in consumer_staple:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        
ma_day = [10, 20, 50]
for ma in ma_day:
    for company in utilities:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()
        
ma_day = [10, 20, 50]
for ma in ma_day:
    for company in etf:
        column_name = f'MA for {ma} days'
        company[column_name] = company['Adj Close'].rolling(ma).mean()

# %%
fig, axes = plt.subplots(nrows=4, ncols=2)
fig.set_figheight(20)
fig.set_figwidth(15)

AAPL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,0])
axes[0,0].set_title('APPLE')

MSFT[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[0,1])
axes[0,1].set_title('MICROSOFT')

CSCO[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,0])
axes[1,0].set_title('Cisco')

INTC[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[1,1])
axes[1,1].set_title('Intel')

ORCL[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[2,0])
axes[2,0].set_title('Oracle')

IBM[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[2,1])
axes[2,1].set_title('IBM')

XLK[['Adj Close', 'MA for 10 days', 'MA for 20 days', 'MA for 50 days']].plot(ax=axes[3,0])
axes[3,0].set_title('Information Technology ETF')

fig.tight_layout()

# %%
# Use pct_change to find the percent change for each day
for company in materials:
    company['Daily Return'] = company['Adj Close'].pct_change()

for company in industrials:
    company['Daily Return'] = company['Adj Close'].pct_change()

for company in financials:
    company['Daily Return'] = company['Adj Close'].pct_change()
    
for company in energy:
    company['Daily Return'] = company['Adj Close'].pct_change()
    
for company in consumer_discretionary:
    company['Daily Return'] = company['Adj Close'].pct_change()
    
for company in info_tech:
    company['Daily Return'] = company['Adj Close'].pct_change()
    
for company in communication:
    company['Daily Return'] = company['Adj Close'].pct_change()
    
for company in real_estate:
    company['Daily Return'] = company['Adj Close'].pct_change()
    
for company in health_care:
    company['Daily Return'] = company['Adj Close'].pct_change()
    
for company in consumer_staple:
    company['Daily Return'] = company['Adj Close'].pct_change()
    
for company in utilities:
    company['Daily Return'] = company['Adj Close'].pct_change()
    
for company in etf:
    company['Daily Return'] = company['Adj Close'].pct_change()

# %%
fig, axes = plt.subplots(nrows=4, ncols=2)
fig.set_figheight(20)
fig.set_figwidth(15)

XOM['Daily Return'].plot(ax=axes[0,0], legend=True, linestyle='--', marker='o')
axes[0,0].set_title('ExxonMobil')

SLB['Daily Return'].plot(ax=axes[0,1], legend=True, linestyle='--', marker='o')
axes[0,1].set_title('Schlumberger')

KMI['Daily Return'].plot(ax=axes[1,0], legend=True, linestyle='--', marker='o')
axes[1,0].set_title('Kinder Morgan')

TSLA['Daily Return'].plot(ax=axes[1,1], legend=True, linestyle='--', marker='o')
axes[1,1].set_title('Tesla')

CVX['Daily Return'].plot(ax=axes[2,0], legend=True, linestyle='--', marker='o')
axes[2,0].set_title('Chevron')

HAL['Daily Return'].plot(ax=axes[2,1], legend=True, linestyle='--', marker='o')
axes[2,1].set_title('Halliburton')

XLE['Daily Return'].plot(ax=axes[3,0], legend=True, linestyle='--', marker='o')
axes[3,0].set_title('Energy ETF')

fig.tight_layout()

# %%
# Relative Strength Index
# Avg(PriceUp)/(Avg(PriceUP)+Avg(PriceDown)*100
# Where: PriceUp(t)=1*(Price(t)-Price(t-1)){Price(t)- Price(t-1)>0};
#        PriceDown(t)=-1*(Price(t)-Price(t-1)){Price(t)- Price(t-1)<0};

def rsi(values):
    up = values[values>0].mean()
    down = -1*values[values<0].mean()
    return 100 * up / (up + down)
